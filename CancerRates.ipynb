# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

#reading data from Excel spreadsheet
df = pd.read_excel(r'Data/SurvivalByStage.xlsx')

print(df)
# Out:
#                   5-year relative survival, 2012-2018  \
# 0   Among cases diagnosed from 2012 to 2018, follo...
# 1   YOU HAVE DOWNLOADED THE FULL DATA SET FOR THIS...
# 2   Data source: Surveillance, Epidemiology, and E...
# 3           © Copyright American Cancer Society, 2018
# 4                                                 NaN
# 5                                         Cancer Type
# 6                      Brain and other nervous system
# 7                                              Breast
# 8                                              Cervix
# 9                                          Colorectum
# 10                                          Esophagus
# 11                                   Hodgkin lymphoma
# 12                            Kidney and renal pelvis
# 13                                             Larynx
# 14                   Liver and intrahepatic bile duct
# 15                                  Lung and bronchus
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

#reading data from Excel spreadsheet
df = pd.read_excel(r'Data/IncRate(1).xlsx', sheet_name='State')

print(df)
# Out:
#                            Incidence rates, 2015-2019  \
# 0   Average annual rate per 100,000, age adjusted ...
# 1   YOU HAVE DOWNLOADED THE FULL DATA SET FOR THIS...
# 2   Data source: North American Association of Cen...
# 3           © Copyright American Cancer Society, 2018
# 4                                                 NaN
# 5                                               State
# 6                                   All U.S. combined
# 7                                             Alabama
# 8                                              Alaska
# 9                                             Arizona
# 10                                           Arkansas
# 11                                         California
# 12                                           Colorado
# 13                                        Connecticut
# 14                                           Delaware
# 15                               District of Columbia
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

#reading data from Excel spreadsheet
df = pd.read_excel(r'Data/IncRate(1).xlsx', sheet_name='Race and ethnicity')

print(df)
# Out:
#                            Incidence rates, 2015-2019  \
# 0   Average annual rate per 100,000, age adjusted ...
# 1   YOU HAVE DOWNLOADED THE FULL DATA SET FOR THIS...
# 2   Data source: North American Association of Cen...
# 3           © Copyright American Cancer Society, 2018
# 4                                                 NaN
# 5                                         Cancer Type
# 6                           All cancer types combined
# 7                      Brain and other nervous system
# 8                                              Breast
# 9                                              Cervix
# 10                           Colon (excluding rectum)
# 11                                         Colorectum
# 12                                          Esophagus
# 13                                   Hodgkin lymphoma
# 14                            Kidney and renal pelvis
# 15                                             Larynx
# ...
